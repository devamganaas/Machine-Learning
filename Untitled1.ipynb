# %% [markdown]
# <a href="https://colab.research.google.com/github/devamganaas/Machine-Learning/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
import numpy as np

# %%
# import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
# create Dataset

# %%
data={
    'Area':[1200,1500,1800,-2400,3000,3500,4000,5000,5500],
    'Bedrooms':[2,3,3,4,5,5,6,6,7],
    'Age':[10,5,8,2,1,3,2,4,1],
    'Distance':[5,3,4,2,1,2,1,3,2],
    'Price':[250,320,340,450,600,650,700,720,800]
}

# %%
# Create DataFrame
df=pd.DataFrame(data)
# display dataset
print("\nDATASET\n")
print(df)
# Out:
# DATASET
#
#    Area  Bedrooms  Age  Distance  Price
# 0  1200         2   10         5    250
# 1  1500         3    5         3    320
# 2  1800         3    8         4    340
# 3 -2400         4    2         2    450
# 4  3000         5    1         1    600
# 5  3500         5    3         2    650
# 6  4000         6    2         1    700
# 7  5000         6    4         3    720
# 8  5500         7    1         2    800

# %%
# prepare Input and Output

# %%
# Independent variables
x=df[['Area','Bedrooms','Age','Distance']]
# Dependent variable
y=df['Price']

# %%
# Build model

# %%
model = LinearRegression()

# %%
# Train model
model.fit(x,y)
# Out:
# LinearRegression()

# %%
# Predictions

# %%
y_pred=model.predict(x)

# %%
# Model parameters

# %%
print("\nMODEL PARAMETERS\n")
print(model.intercept_)
print("\nCoefficient:")
for feature, coef in zip(x.columns,model.coef_):
    print(feature,":",coef)
# Out:
# MODEL PARAMETERS
#
# 1.1479326669008287
#
# Coefficient:
# Area : 0.003647455448312503
# Bedrooms : 117.91170057739271
# Age : 7.894383331486665
# Distance : -16.659353846293392

# %%
# Regression Equation

# %%
print("\nREGRESSION EQUATION\n")
print("price =")
for feature,coef in zip(x.columns,model.coef_):
    print(f"({coef:.4f} * {feature}) +")
print(model.intercept_)
# Out:
# REGRESSION EQUATION
#
# price =
# (0.0036 * Area) +
# (117.9117 * Bedrooms) +
# (7.8944 * Age) +
# (-16.6594 * Distance) +
# 1.1479326669008287

# %%
# Evaluaion Metrics

# %%
mse = mean_squared_error(y,y_pred)
r2 = r2_score(y,y_pred)
print("\nEVALUATION METRICS\n")
print("Mean Squared Error (MSE):",round(mse,4))
print("R-squared score:",round(r2,4))
# Out:
# EVALUATION METRICS
#
# Mean Squared Error (MSE): 631.1309
# R-squared score: 0.9823

# %%
# predict New House Price

# %%
new_house = pd.DataFrame({'Area':[2800],'Bedrooms':[4],'Age':[2],'Distance':[2]})
predicted_price= model.predict(new_house)
print("\nNEW HOUSE PREDICTION\n")
print("Predicted House price:",round(predicted_price[0],2))
# Out:
# NEW HOUSE PREDICTION
#
# Predicted House price: 465.48

# %%
# visualization

# %%
plt.figure(figsize=(8,6))
plt.scatter(y,y_pred,color='blue')
plt.plot([y.min(),y.max()],[y.min(),y.max()],color='red')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual vs Predicted House Prices')
plt.grid(True)
plt.show()
